# %% [markdown]
# # **Feteching issues from a GitHub repository using requests**

# %%
import os
import requests
from dotenv import load_dotenv
from langchain_core.documents import Document

load_dotenv()

github_api_token = os.getenv("GITHUB_API_TOKEN")

    
# Add headers to avoid rate limiting issues
headers = {
    'Accept': 'application/vnd.github.v3+json',
    'User-Agent': 'Python-GitHub-Issues-Example'
}
    
owner = "langflow-ai"
repo = "langflow"
url = f"https://api.github.com/repos/{owner}/{repo}/issues"

response = requests.get(url, headers=headers)
        
# Check if the request was successful
if response.status_code == 200:
    doc = []
    issues = response.json()
    print(f"\nFetching issues from {owner}/{repo}:")
    print("-" * 50)
    for issue in issues: 
        print(f"\nIssue #{issue['number']}")
        print(f"Title: {issue['title']}")
        print(f"State: {issue['state']}")
        print(f"Created at: {issue['created_at']}")
        print(f"URL: {issue['html_url']}")
        print("-" * 50)
else:
    print(f"Failed to fetch issues. Status code: {response.status_code}")
# Out:
# Fetching issues from langflow-ai/langflow:
# --------------------------------------------------
#
# Issue #4774
# Title: fix: enhance Filter Data with JQ Query, Column Selection and Index selection"
# State: open
# Created at: 2024-11-21T23:49:58Z
# URL: https://github.com/langflow-ai/langflow/pull/4774
# --------------------------------------------------
#
# Issue #4772
# Title: docs: add API documentation and restructure sidebar
# State: open
# Created at: 2024-11-21T20:35:18Z
# URL: https://github.com/langflow-ai/langflow/pull/4772
# --------------------------------------------------
#
# Issue #4771
# Title: refactor: improve test speed for Blog Writer integration
# State: open
# Created at: 2024-11-21T20:20:27Z
# URL: https://github.com/langflow-ai/langflow/pull/4771
# --------------------------------------------------
#
# Issue #4770
# Title: refactor: improve waiting logic in Basic Prompting test
# State: open
# Created at: 2024-11-21T20:10:22Z
# URL: https://github.com/langflow-ai/langflow/pull/4770
# --------------------------------------------------
#
# Issue #4768
# Title: fix: do not render page while examples are loading
# State: open
# Created at: 2024-11-21T17:37:31Z
# URL: https://github.com/langflow-ai/langflow/pull/4768
# --------------------------------------------------
#
# Issue #4767
# Title: fix: remove useSidebar to fix errors of SidebarWrapper when opening playground page
# State: open
# Created at: 2024-11-21T17:25:49Z
# URL: https://github.com/langflow-ai/langflow/pull/4767
# --------------------------------------------------
#
# Issue #4766
# Title: fix: changed tooltip position on playground to improve visibility, fixed color of theme switcher on light mode
# State: open
# Created at: 2024-11-21T16:50:47Z
# URL: https://github.com/langflow-ai/langflow/pull/4766
# --------------------------------------------------
#
# Issue #4765
# Title: fix: update edge z index when node is selected
# State: open
# Created at: 2024-11-21T16:38:32Z
# URL: https://github.com/langflow-ai/langflow/pull/4765
# --------------------------------------------------
#
# Issue #4763
# Title: fix: update all outdated components at once
# State: open
# Created at: 2024-11-21T15:43:50Z
# URL: https://github.com/langflow-ai/langflow/pull/4763
# --------------------------------------------------
#
# Issue #4762
# Title: fix: refactor get all to fix types not being fetched before checking for outdated components
# State: open
# Created at: 2024-11-21T15:40:50Z
# URL: https://github.com/langflow-ai/langflow/pull/4762
# --------------------------------------------------
#
# Issue #4761
# Title: fix: update design of update component
# State: open
# Created at: 2024-11-21T15:37:59Z
# URL: https://github.com/langflow-ai/langflow/pull/4761
# --------------------------------------------------
#
# Issue #4760
# Title: feat: add Google icons to search-related components
# State: open
# Created at: 2024-11-21T15:36:49Z
# URL: https://github.com/langflow-ai/langflow/pull/4760
# --------------------------------------------------
#
# Issue #4758
# Title: fix:  Error in SerpAPI search: cannot access local variable 'wrapper' where it is not associated with a value
# State: open
# Created at: 2024-11-21T15:32:50Z
# URL: https://github.com/langflow-ai/langflow/pull/4758
# --------------------------------------------------
#
# Issue #4757
# Title: chore: remove legacy component checks and alerts
# State: open
# Created at: 2024-11-21T15:28:10Z
# URL: https://github.com/langflow-ai/langflow/pull/4757
# --------------------------------------------------
#
# Issue #4756
# Title: fix: Add icon to SpiderTool and SQLDatabaseComponent classes
# State: open
# Created at: 2024-11-21T15:27:33Z
# URL: https://github.com/langflow-ai/langflow/pull/4756
# --------------------------------------------------
#
# Issue #4754
# Title: feat: rename MetaphorToolkit file to ExaSearchToolkit and update component icons
# State: open
# Created at: 2024-11-21T15:18:16Z
# URL: https://github.com/langflow-ai/langflow/pull/4754
# --------------------------------------------------
#
# Issue #4753
# Title: feat: Add FolderSync icon to UpdateDataComponent in update_data.py
# State: open
# Created at: 2024-11-21T15:00:26Z
# URL: https://github.com/langflow-ai/langflow/pull/4753
# --------------------------------------------------
#
# Issue #4748
# Title: Add LiteLLM Connector
# State: open
# Created at: 2024-11-21T06:31:58Z
# URL: https://github.com/langflow-ai/langflow/issues/4748
# --------------------------------------------------
#
# Issue #4745
# Title: docs: enhance Google Cloud Vertex AI setup guide for Langflow
# State: open
# Created at: 2024-11-21T01:13:25Z
# URL: https://github.com/langflow-ai/langflow/pull/4745
# --------------------------------------------------
#
# Issue #4744
# Title: Refactor NoticeAlert: Improve Timeout Handling, Simplify Link Logic, and Enhance Cleanup
# State: open
# Created at: 2024-11-21T00:19:37Z
# URL: https://github.com/langflow-ai/langflow/pull/4744
# --------------------------------------------------
#
# Issue #4738
# Title: Expanding Unstructured loader to take server file inputs, more file types, and API parameters
# State: open
# Created at: 2024-11-20T17:01:04Z
# URL: https://github.com/langflow-ai/langflow/pull/4738
# --------------------------------------------------
#
# Issue #4736
# Title: Filter by version
# State: open
# Created at: 2024-11-20T15:46:14Z
# URL: https://github.com/langflow-ai/langflow/issues/4736
# --------------------------------------------------
#
# Issue #4735
# Title: After upgrade to version 1.1.0, the old flows fail to build because components are out of date
# State: open
# Created at: 2024-11-20T15:30:38Z
# URL: https://github.com/langflow-ai/langflow/issues/4735
# --------------------------------------------------
#
# Issue #4733
# Title: feat(components): integrate Spacy NLP toolset into Langflow component…
# State: open
# Created at: 2024-11-20T15:17:18Z
# URL: https://github.com/langflow-ai/langflow/pull/4733
# --------------------------------------------------
#
# Issue #4732
# Title: fix(astradb_tools): sets some options as Advanced and improves descriptions
# State: open
# Created at: 2024-11-20T14:33:45Z
# URL: https://github.com/langflow-ai/langflow/pull/4732
# --------------------------------------------------
#
# Issue #4731
# Title: Creating BaseFileComponent, integrating with API Request "to file" feature
# State: open
# Created at: 2024-11-20T14:08:45Z
# URL: https://github.com/langflow-ai/langflow/pull/4731
# --------------------------------------------------
#
# Issue #4730
# Title: LangFlow suddenly crashed and can no longer be started
# State: open
# Created at: 2024-11-20T03:39:20Z
# URL: https://github.com/langflow-ai/langflow/issues/4730
# --------------------------------------------------
#
# Issue #4729
# Title: Groq in the Agent component is not loading models
# State: open
# Created at: 2024-11-20T01:59:05Z
# URL: https://github.com/langflow-ai/langflow/issues/4729
# --------------------------------------------------
#
# Issue #4728
# Title: Ollama Embeddings is faulty in v1.1 :  Error building Component Ollama Embeddings: Could not connect to Ollama API.
# State: open
# Created at: 2024-11-20T00:14:53Z
# URL: https://github.com/langflow-ai/langflow/issues/4728
# --------------------------------------------------
#
# Issue #4725
# Title: Error running graph: Error building Agent :  All of session_id, sender, and sender_name must be provided
# State: open
# Created at: 2024-11-19T22:36:12Z
# URL: https://github.com/langflow-ai/langflow/issues/4725
# --------------------------------------------------

# %%
{
   "url":"https://api.github.com/repos/langflow-ai/langflow/issues/4774",
   "repository_url":"https://api.github.com/repos/langflow-ai/langflow",
   "labels_url":"https://api.github.com/repos/langflow-ai/langflow/issues/4774/labels{/name}",
   "comments_url":"https://api.github.com/repos/langflow-ai/langflow/issues/4774/comments",
   "events_url":"https://api.github.com/repos/langflow-ai/langflow/issues/4774/events",
   "html_url":"https://github.com/langflow-ai/langflow/pull/4774",
   "id":2681346280,
   "node_id":"PR_kwDOI7jmA86CvaRz",
   "number":4774,
   "title":"fix: enhance Filter Data with JQ Query, Column Selection and Index selection\"",
   "user":{
      "login":"vasconceloscezar",
      "id":97035956,
      "node_id":"U_kgDOBcimtA",
      "avatar_url":"https://avatars.githubusercontent.com/u/97035956?v=4",
      "gravatar_id":"",
      "url":"https://api.github.com/users/vasconceloscezar",
      "html_url":"https://github.com/vasconceloscezar",
      "followers_url":"https://api.github.com/users/vasconceloscezar/followers",
      "following_url":"https://api.github.com/users/vasconceloscezar/following{/other_user}",
      "gists_url":"https://api.github.com/users/vasconceloscezar/gists{/gist_id}",
      "starred_url":"https://api.github.com/users/vasconceloscezar/starred{/owner}{/repo}",
      "subscriptions_url":"https://api.github.com/users/vasconceloscezar/subscriptions",
      "organizations_url":"https://api.github.com/users/vasconceloscezar/orgs",
      "repos_url":"https://api.github.com/users/vasconceloscezar/repos",
      "events_url":"https://api.github.com/users/vasconceloscezar/events{/privacy}",
      "received_events_url":"https://api.github.com/users/vasconceloscezar/received_events",
      "type":"User",
      "user_view_type":"public",
      "site_admin":false
   },
   "labels":[
      {
         "id":5132979269,
         "node_id":"LA_kwDOI7jmA88AAAABMfMMRQ",
         "url":"https://api.github.com/repos/langflow-ai/langflow/labels/bug",
         "name":"bug",
         "color":"d73a4a",
         "default":true,
         "description":"Something isn't working"
      },
      {
         "id":6322792115,
         "node_id":"LA_kwDOI7jmA88AAAABeN4msw",
         "url":"https://api.github.com/repos/langflow-ai/langflow/labels/size:L",
         "name":"size:L",
         "color":"eb9500",
         "default":false,
         "description":"This PR changes 100-499 lines, ignoring generated files."
      }
   ],
   "state":"open",
   "locked":false,
   "assignee":"None",
   "assignees":[
      
   ],
   "milestone":"None",
   "comments":0,
   "created_at":"2024-11-21T23:49:58Z",
   "updated_at":"2024-11-22T00:06:59Z",
   "closed_at":"None",
   "author_association":"COLLABORATOR",
   "active_lock_reason":"None",
   "draft":false,
   "pull_request":{
      "url":"https://api.github.com/repos/langflow-ai/langflow/pulls/4774",
      "html_url":"https://github.com/langflow-ai/langflow/pull/4774",
      "diff_url":"https://github.com/langflow-ai/langflow/pull/4774.diff",
      "patch_url":"https://github.com/langflow-ai/langflow/pull/4774.patch",
      "merged_at":"None"
   },
   "body":"Consolidates JSON parsing, data filtering, and key extraction into a single streamlined component. Adds support for JQ queries, column selection, and index-based filtering, eliminating the need for separate Parse JSON and Extract Key components.\r\n\r\n![image](https://github.com/user-attachments/assets/f3a34231-a693-4319-a235-c0be5e253959)\r\n\r\nIf this is approved we can remove the following: \r\n\r\n`src/backend/base/langflow/components/processing/extract_key.py`\r\n`src/backend/base/langflow/components/processing/filter_data_values.py`\r\n`src/backend/base/langflow/components/processing/parse_json_data.py`\r\n\r\n\r\n",
   "closed_by":"None",
   "reactions":{
      "url":"https://api.github.com/repos/langflow-ai/langflow/issues/4774/reactions",
      "total_count":0,
      "+1":0,
      "-1":0,
      "laugh":0,
      "hooray":0,
      "confused":0,
      "heart":0,
      "rocket":0,
      "eyes":0
   },
   "timeline_url":"https://api.github.com/repos/langflow-ai/langflow/issues/4774/timeline",
   "performed_via_github_app":"None",
   "state_reason":"None"
}

# %% [markdown]
# # **Feteching issues from a GitHub repository using PyGitHub**

# %%
load_dotenv()

repo_name="langflow-ai/langflow"
# Get GitHub token from environment variables (if available)
github_token = os.getenv('GITHUB_TOKEN')

g = Github(github_token)
        
# Get the repository
repo = g.get_repo(repo_name)

# Get issues
issues = repo.get_issues(state='open')

print(f"\nFetching issues from {repo_name}:")
print("-" * 50)

# Print each issue
for issue in issues:
    print(issue)
    print(f"\nIssue #{issue.number}")
    print(f"Title: {issue.title}")
    print(f"State: {issue.state}")
    print(f"Created at: {issue.created_at}")
    print(f"URL: {issue.html_url}")
    print("-" * 50)
# Out:
# Fetching issues from langflow-ai/langflow:
# --------------------------------------------------
# Issue(title="fix: enhance Filter Data with JQ Query, Column Selection and Index selection"", number=4774)
#
# Issue #4774
# Title: fix: enhance Filter Data with JQ Query, Column Selection and Index selection"
# State: open
# Created at: 2024-11-21 23:49:58+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4774
# --------------------------------------------------
# Issue(title="docs: add API documentation and restructure sidebar", number=4772)
#
# Issue #4772
# Title: docs: add API documentation and restructure sidebar
# State: open
# Created at: 2024-11-21 20:35:18+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4772
# --------------------------------------------------
# Issue(title="refactor: improve test speed for Blog Writer integration", number=4771)
#
# Issue #4771
# Title: refactor: improve test speed for Blog Writer integration
# State: open
# Created at: 2024-11-21 20:20:27+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4771
# --------------------------------------------------
# Issue(title="refactor: improve waiting logic in Basic Prompting test", number=4770)
#
# Issue #4770
# Title: refactor: improve waiting logic in Basic Prompting test
# State: open
# Created at: 2024-11-21 20:10:22+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4770
# --------------------------------------------------
# Issue(title="fix: do not render page while examples are loading", number=4768)
#
# Issue #4768
# Title: fix: do not render page while examples are loading
# State: open
# Created at: 2024-11-21 17:37:31+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4768
# --------------------------------------------------
# Issue(title="fix: remove useSidebar to fix errors of SidebarWrapper when opening playground page", number=4767)
#
# Issue #4767
# Title: fix: remove useSidebar to fix errors of SidebarWrapper when opening playground page
# State: open
# Created at: 2024-11-21 17:25:49+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4767
# --------------------------------------------------
# Issue(title="fix: changed tooltip position on playground to improve visibility, fixed color of theme switcher on light mode", number=4766)
#
# Issue #4766
# Title: fix: changed tooltip position on playground to improve visibility, fixed color of theme switcher on light mode
# State: open
# Created at: 2024-11-21 16:50:47+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4766
# --------------------------------------------------
# Issue(title="fix: update edge z index when node is selected", number=4765)
#
# Issue #4765
# Title: fix: update edge z index when node is selected
# State: open
# Created at: 2024-11-21 16:38:32+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4765
# --------------------------------------------------
# Issue(title="fix: update all outdated components at once", number=4763)
#
# Issue #4763
# Title: fix: update all outdated components at once
# State: open
# Created at: 2024-11-21 15:43:50+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4763
# --------------------------------------------------
# Issue(title="fix: refactor get all to fix types not being fetched before checking for outdated components", number=4762)
#
# Issue #4762
# Title: fix: refactor get all to fix types not being fetched before checking for outdated components
# State: open
# Created at: 2024-11-21 15:40:50+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4762
# --------------------------------------------------
# Issue(title="fix: update design of update component", number=4761)
#
# Issue #4761
# Title: fix: update design of update component
# State: open
# Created at: 2024-11-21 15:37:59+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4761
# --------------------------------------------------
# Issue(title="feat: add Google icons to search-related components", number=4760)
#
# Issue #4760
# Title: feat: add Google icons to search-related components
# State: open
# Created at: 2024-11-21 15:36:49+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4760
# --------------------------------------------------
# Issue(title="fix:  Error in SerpAPI search: cannot access local variable 'wrapper' where it is not associated with a value", number=4758)
#
# Issue #4758
# Title: fix:  Error in SerpAPI search: cannot access local variable 'wrapper' where it is not associated with a value
# State: open
# Created at: 2024-11-21 15:32:50+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4758
# --------------------------------------------------
# Issue(title="chore: remove legacy component checks and alerts", number=4757)
#
# Issue #4757
# Title: chore: remove legacy component checks and alerts
# State: open
# Created at: 2024-11-21 15:28:10+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4757
# --------------------------------------------------
# Issue(title="fix: Add icon to SpiderTool and SQLDatabaseComponent classes", number=4756)
#
# Issue #4756
# Title: fix: Add icon to SpiderTool and SQLDatabaseComponent classes
# State: open
# Created at: 2024-11-21 15:27:33+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4756
# --------------------------------------------------
# Issue(title="feat: rename MetaphorToolkit file to ExaSearchToolkit and update component icons", number=4754)
#
# Issue #4754
# Title: feat: rename MetaphorToolkit file to ExaSearchToolkit and update component icons
# State: open
# Created at: 2024-11-21 15:18:16+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4754
# --------------------------------------------------
# Issue(title="feat: Add FolderSync icon to UpdateDataComponent in update_data.py", number=4753)
#
# Issue #4753
# Title: feat: Add FolderSync icon to UpdateDataComponent in update_data.py
# State: open
# Created at: 2024-11-21 15:00:26+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4753
# --------------------------------------------------
# Issue(title="Add LiteLLM Connector", number=4748)
#
# Issue #4748
# Title: Add LiteLLM Connector
# State: open
# Created at: 2024-11-21 06:31:58+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4748
# --------------------------------------------------
# Issue(title="docs: enhance Google Cloud Vertex AI setup guide for Langflow", number=4745)
#
# Issue #4745
# Title: docs: enhance Google Cloud Vertex AI setup guide for Langflow
# State: open
# Created at: 2024-11-21 01:13:25+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4745
# --------------------------------------------------
# Issue(title="Refactor NoticeAlert: Improve Timeout Handling, Simplify Link Logic, and Enhance Cleanup", number=4744)
#
# Issue #4744
# Title: Refactor NoticeAlert: Improve Timeout Handling, Simplify Link Logic, and Enhance Cleanup
# State: open
# Created at: 2024-11-21 00:19:37+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4744
# --------------------------------------------------
# Issue(title="Expanding Unstructured loader to take server file inputs, more file types, and API parameters", number=4738)
#
# Issue #4738
# Title: Expanding Unstructured loader to take server file inputs, more file types, and API parameters
# State: open
# Created at: 2024-11-20 17:01:04+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4738
# --------------------------------------------------
# Issue(title="Filter by version", number=4736)
#
# Issue #4736
# Title: Filter by version
# State: open
# Created at: 2024-11-20 15:46:14+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4736
# --------------------------------------------------
# Issue(title="After upgrade to version 1.1.0, the old flows fail to build because components are out of date", number=4735)
#
# Issue #4735
# Title: After upgrade to version 1.1.0, the old flows fail to build because components are out of date
# State: open
# Created at: 2024-11-20 15:30:38+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4735
# --------------------------------------------------
# Issue(title="feat(components): integrate Spacy NLP toolset into Langflow component…", number=4733)
#
# Issue #4733
# Title: feat(components): integrate Spacy NLP toolset into Langflow component…
# State: open
# Created at: 2024-11-20 15:17:18+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4733
# --------------------------------------------------
# Issue(title="fix(astradb_tools): sets some options as Advanced and improves descriptions", number=4732)
#
# Issue #4732
# Title: fix(astradb_tools): sets some options as Advanced and improves descriptions
# State: open
# Created at: 2024-11-20 14:33:45+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4732
# --------------------------------------------------
# Issue(title="Creating BaseFileComponent, integrating with API Request "to file" feature", number=4731)
#
# Issue #4731
# Title: Creating BaseFileComponent, integrating with API Request "to file" feature
# State: open
# Created at: 2024-11-20 14:08:45+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4731
# --------------------------------------------------
# Issue(title="LangFlow suddenly crashed and can no longer be started", number=4730)
#
# Issue #4730
# Title: LangFlow suddenly crashed and can no longer be started
# State: open
# Created at: 2024-11-20 03:39:20+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4730
# --------------------------------------------------
# Issue(title="Groq in the Agent component is not loading models ", number=4729)
#
# Issue #4729
# Title: Groq in the Agent component is not loading models
# State: open
# Created at: 2024-11-20 01:59:05+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4729
# --------------------------------------------------
# Issue(title="Ollama Embeddings is faulty in v1.1 :  Error building Component Ollama Embeddings: Could not connect to Ollama API.", number=4728)
#
# Issue #4728
# Title: Ollama Embeddings is faulty in v1.1 :  Error building Component Ollama Embeddings: Could not connect to Ollama API.
# State: open
# Created at: 2024-11-20 00:14:53+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4728
# --------------------------------------------------
# Issue(title="Error running graph: Error building Agent :  All of session_id, sender, and sender_name must be provided", number=4725)
#
# Issue #4725
# Title: Error running graph: Error building Agent :  All of session_id, sender, and sender_name must be provided
# State: open
# Created at: 2024-11-19 22:36:12+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4725
# --------------------------------------------------
# Issue(title="feat(components): add LangWatch evaluator component - New Bundle", number=4722)
#
# Issue #4722
# Title: feat(components): add LangWatch evaluator component - New Bundle
# State: open
# Created at: 2024-11-19 20:51:23+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4722
# --------------------------------------------------
# Issue(title="refactor: Replace InputComponent with Select dropdown", number=4719)
#
# Issue #4719
# Title: refactor: Replace InputComponent with Select dropdown
# State: open
# Created at: 2024-11-19 19:27:38+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4719
# --------------------------------------------------
# Issue(title="Invalid API Key error while using Groq api key with Crew AI Sequential Crew component on Datastax Langflow", number=4718)
#
# Issue #4718
# Title: Invalid API Key error while using Groq api key with Crew AI Sequential Crew component on Datastax Langflow
# State: open
# Created at: 2024-11-19 18:28:18+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4718
# --------------------------------------------------
# Issue(title="Support tracing config at component level", number=4713)
#
# Issue #4713
# Title: Support tracing config at component level
# State: open
# Created at: 2024-11-19 17:37:37+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4713
# --------------------------------------------------
# Issue(title="feat: Add PlaygroundButton component to flow toolbar", number=4712)
#
# Issue #4712
# Title: feat: Add PlaygroundButton component to flow toolbar
# State: open
# Created at: 2024-11-19 16:55:18+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4712
# --------------------------------------------------
# Issue(title="Improve PDF parsing results for a broader range of documents", number=4710)
#
# Issue #4710
# Title: Improve PDF parsing results for a broader range of documents
# State: open
# Created at: 2024-11-19 16:26:06+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4710
# --------------------------------------------------
# Issue(title="docs: add documentation for external database configuration", number=4707)
#
# Issue #4707
# Title: docs: add documentation for external database configuration
# State: open
# Created at: 2024-11-19 15:10:50+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4707
# --------------------------------------------------
# Issue(title="ref: Add aiofile to do async file operations", number=4705)
#
# Issue #4705
# Title: ref: Add aiofile to do async file operations
# State: open
# Created at: 2024-11-19 14:43:29+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4705
# --------------------------------------------------
# Issue(title="ref: Apply ruff rules preview autofix", number=4699)
#
# Issue #4699
# Title: ref: Apply ruff rules preview autofix
# State: open
# Created at: 2024-11-19 13:42:08+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4699
# --------------------------------------------------
# Issue(title="ref: Remove usage of deprecated get_event_loop", number=4697)
#
# Issue #4697
# Title: ref: Remove usage of deprecated get_event_loop
# State: open
# Created at: 2024-11-19 12:56:52+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4697
# --------------------------------------------------
# Issue(title="Error building component FILE: bad offset for central directory", number=4695)
#
# Issue #4695
# Title: Error building component FILE: bad offset for central directory
# State: open
# Created at: 2024-11-19 09:46:37+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4695
# --------------------------------------------------
# Issue(title="fix: Use AsyncSession in crud log and find_flow", number=4691)
#
# Issue #4691
# Title: fix: Use AsyncSession in crud log and find_flow
# State: open
# Created at: 2024-11-18 23:01:14+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4691
# --------------------------------------------------
# Issue(title="tests: organize playwright tests by feature suites and optimize CI runtime", number=4687)
#
# Issue #4687
# Title: tests: organize playwright tests by feature suites and optimize CI runtime
# State: open
# Created at: 2024-11-18 18:28:03+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4687
# --------------------------------------------------
# Issue(title="LangFlow 1.1.0 crashes on startup without root fs permissions", number=4684)
#
# Issue #4684
# Title: LangFlow 1.1.0 crashes on startup without root fs permissions
# State: open
# Created at: 2024-11-18 17:30:08+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4684
# --------------------------------------------------
# Issue(title="adding ability for APIRequest to retry and save to a file", number=4677)
#
# Issue #4677
# Title: adding ability for APIRequest to retry and save to a file
# State: open
# Created at: 2024-11-18 16:13:57+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4677
# --------------------------------------------------
# Issue(title="fix: Improve waiting logic in tweksTest.spec.ts", number=4674)
#
# Issue #4674
# Title: fix: Improve waiting logic in tweksTest.spec.ts
# State: open
# Created at: 2024-11-18 14:57:12+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4674
# --------------------------------------------------
# Issue(title="fix: Improve wait time in saveComponents.spec.ts", number=4673)
#
# Issue #4673
# Title: fix: Improve wait time in saveComponents.spec.ts
# State: open
# Created at: 2024-11-18 14:35:49+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4673
# --------------------------------------------------
# Issue(title="fix: Improve waiting logic in playground.spec.ts", number=4672)
#
# Issue #4672
# Title: fix: Improve waiting logic in playground.spec.ts
# State: open
# Created at: 2024-11-18 14:20:49+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4672
# --------------------------------------------------
# Issue(title="fix:  traces inputs and outputs not being sent to tracing services", number=4669)
#
# Issue #4669
# Title: fix:  traces inputs and outputs not being sent to tracing services
# State: open
# Created at: 2024-11-18 13:16:54+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4669
# --------------------------------------------------
# Issue(title="fix: Use AsyncSession in memory", number=4665)
#
# Issue #4665
# Title: fix: Use AsyncSession in memory
# State: open
# Created at: 2024-11-18 12:06:03+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4665
# --------------------------------------------------
# Issue(title="OpenAI-Like API support", number=4664)
#
# Issue #4664
# Title: OpenAI-Like API support
# State: open
# Created at: 2024-11-18 11:41:08+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4664
# --------------------------------------------------
# Issue(title="feat: add needle as custom component", number=4657)
#
# Issue #4657
# Title: feat: add needle as custom component
# State: open
# Created at: 2024-11-17 17:12:13+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4657
# --------------------------------------------------
# Issue(title="FileUpload not load the name into the path", number=4654)
#
# Issue #4654
# Title: FileUpload not load the name into the path
# State: open
# Created at: 2024-11-16 22:28:25+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4654
# --------------------------------------------------
# Issue(title="No stream_url when using Tool Calling Agent", number=4652)
#
# Issue #4652
# Title: No stream_url when using Tool Calling Agent
# State: open
# Created at: 2024-11-16 20:02:19+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4652
# --------------------------------------------------
# Issue(title="fix: typo inside teardown_superuser function", number=4651)
#
# Issue #4651
# Title: fix: typo inside teardown_superuser function
# State: open
# Created at: 2024-11-16 18:51:27+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4651
# --------------------------------------------------
# Issue(title="fix: Use AsyncSession in some API endpoints", number=4650)
#
# Issue #4650
# Title: fix: Use AsyncSession in some API endpoints
# State: open
# Created at: 2024-11-16 16:58:36+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4650
# --------------------------------------------------
# Issue(title="Amazon bedrock compatibility issue in Agent component in certain rare specific use cases", number=4648)
#
# Issue #4648
# Title: Amazon bedrock compatibility issue in Agent component in certain rare specific use cases
# State: open
# Created at: 2024-11-15 22:45:55+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4648
# --------------------------------------------------
# Issue(title="feat: voice mode", number=4642)
#
# Issue #4642
# Title: feat: voice mode
# State: open
# Created at: 2024-11-15 19:25:01+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4642
# --------------------------------------------------
# Issue(title="feat: add golang in tab for integration", number=4641)
#
# Issue #4641
# Title: feat: add golang in tab for integration
# State: open
# Created at: 2024-11-15 19:00:46+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4641
# --------------------------------------------------
# Issue(title="Compatibility Issue: Tool-Calling Agent and Components with Build Tools and Predefined Argument Schemas", number=4640)
#
# Issue #4640
# Title: Compatibility Issue: Tool-Calling Agent and Components with Build Tools and Predefined Argument Schemas
# State: open
# Created at: 2024-11-15 18:54:54+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4640
# --------------------------------------------------
# Issue(title="Update All Components to Latest Versions Automatically/ single button to do that", number=4639)
#
# Issue #4639
# Title: Update All Components to Latest Versions Automatically/ single button to do that
# State: open
# Created at: 2024-11-15 18:09:32+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4639
# --------------------------------------------------
# Issue(title="feat: new AddMetadataComponent enhances Data and Message objects with dict or Data object entries", number=4634)
#
# Issue #4634
# Title: feat: new AddMetadataComponent enhances Data and Message objects with dict or Data object entries
# State: open
# Created at: 2024-11-15 13:42:29+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4634
# --------------------------------------------------
# Issue(title="Ollama Embedding issue", number=4633)
#
# Issue #4633
# Title: Ollama Embedding issue
# State: open
# Created at: 2024-11-15 08:43:06+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4633
# --------------------------------------------------
# Issue(title="Memory not clearing", number=4631)
#
# Issue #4631
# Title: Memory not clearing
# State: open
# Created at: 2024-11-15 06:15:00+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4631
# --------------------------------------------------
# Issue(title="feat: improve composio oauth experience", number=4613)
#
# Issue #4613
# Title: feat: improve composio oauth experience
# State: open
# Created at: 2024-11-14 17:31:04+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4613
# --------------------------------------------------
# Issue(title="fix: Removed condition for importing flows", number=4611)
#
# Issue #4611
# Title: fix: Removed condition for importing flows
# State: open
# Created at: 2024-11-14 17:25:04+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4611
# --------------------------------------------------
# Issue(title="refactor: Improve componentHoverAdd.spec test ", number=4608)
#
# Issue #4608
# Title: refactor: Improve componentHoverAdd.spec test
# State: open
# Created at: 2024-11-14 16:55:10+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4608
# --------------------------------------------------
# Issue(title="feat: Add JSON patch functionality and asynchronous message handling", number=4600)
#
# Issue #4600
# Title: feat: Add JSON patch functionality and asynchronous message handling
# State: open
# Created at: 2024-11-14 14:16:31+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4600
# --------------------------------------------------
# Issue(title="feat: adding list of Data output to Parse Data", number=4598)
#
# Issue #4598
# Title: feat: adding list of Data output to Parse Data
# State: open
# Created at: 2024-11-14 13:53:50+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4598
# --------------------------------------------------
# Issue(title="I18n support", number=4592)
#
# Issue #4592
# Title: I18n support
# State: open
# Created at: 2024-11-14 08:27:04+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4592
# --------------------------------------------------
# Issue(title="[Component Bug] Conditional Router(If-Else in 1.1.0) Cannot Stop Correctly", number=4590)
#
# Issue #4590
# Title: [Component Bug] Conditional Router(If-Else in 1.1.0) Cannot Stop Correctly
# State: open
# Created at: 2024-11-14 06:34:10+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4590
# --------------------------------------------------
# Issue(title="After installing the latest version 1.1.0, it keeps on STARTING!", number=4588)
#
# Issue #4588
# Title: After installing the latest version 1.1.0, it keeps on STARTING!
# State: open
# Created at: 2024-11-14 03:12:15+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4588
# --------------------------------------------------
# Issue(title="Added support for on-prem huggingface embeddings", number=4575)
#
# Issue #4575
# Title: Added support for on-prem huggingface embeddings
# State: open
# Created at: 2024-11-13 18:29:56+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4575
# --------------------------------------------------
# Issue(title="feat: disable browser autocomplete on popover input fields", number=4573)
#
# Issue #4573
# Title: feat: disable browser autocomplete on popover input fields
# State: open
# Created at: 2024-11-13 17:51:24+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4573
# --------------------------------------------------
# Issue(title="Can't modify worker timeout", number=4570)
#
# Issue #4570
# Title: Can't modify worker timeout
# State: open
# Created at: 2024-11-13 15:29:29+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4570
# --------------------------------------------------
# Issue(title="feat: support tongyi model and embeddings api", number=4562)
#
# Issue #4562
# Title: feat: support tongyi model and embeddings api
# State: open
# Created at: 2024-11-13 05:58:06+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4562
# --------------------------------------------------
# Issue(title="feat: LLM routing integration via NotDiamond", number=4543)
#
# Issue #4543
# Title: feat: LLM routing integration via NotDiamond
# State: open
# Created at: 2024-11-12 18:49:41+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4543
# --------------------------------------------------
# Issue(title="DOCS: Update documentation with new installation method.", number=4540)
#
# Issue #4540
# Title: DOCS: Update documentation with new installation method.
# State: open
# Created at: 2024-11-12 18:31:19+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4540
# --------------------------------------------------
# Issue(title="feat: adding ollama to agent Component", number=4531)
#
# Issue #4531
# Title: feat: adding ollama to agent Component
# State: open
# Created at: 2024-11-12 16:40:36+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4531
# --------------------------------------------------
# Issue(title="Can't access flow directly by link", number=4528)
#
# Issue #4528
# Title: Can't access flow directly by link
# State: open
# Created at: 2024-11-12 15:24:18+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4528
# --------------------------------------------------
# Issue(title="Can't make simple tool agent (google api) : "Too many arguments to single-input tool google_search"", number=4518)
#
# Issue #4518
# Title: Can't make simple tool agent (google api) : "Too many arguments to single-input tool google_search"
# State: open
# Created at: 2024-11-12 07:56:29+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4518
# --------------------------------------------------
# Issue(title="Network error in time demanding flows", number=4499)
#
# Issue #4499
# Title: Network error in time demanding flows
# State: open
# Created at: 2024-11-11 18:13:13+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4499
# --------------------------------------------------
# Issue(title="`Conditional Router` does not stop correctly", number=4490)
#
# Issue #4490
# Title: `Conditional Router` does not stop correctly
# State: open
# Created at: 2024-11-11 09:35:44+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4490
# --------------------------------------------------
# Issue(title="Improve CONTRIBUTING.md for Windows and WSL users", number=4475)
#
# Issue #4475
# Title: Improve CONTRIBUTING.md for Windows and WSL users
# State: open
# Created at: 2024-11-08 16:26:49+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4475
# --------------------------------------------------
# Issue(title="Unable to install Langflow on Windows w/ Python 3.13", number=4474)
#
# Issue #4474
# Title: Unable to install Langflow on Windows w/ Python 3.13
# State: open
# Created at: 2024-11-08 16:09:17+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4474
# --------------------------------------------------
# Issue(title="APIRequest response data types getting mangled in Data object", number=4472)
#
# Issue #4472
# Title: APIRequest response data types getting mangled in Data object
# State: open
# Created at: 2024-11-08 15:54:28+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4472
# --------------------------------------------------
# Issue(title="Have an easy way to let the agent initiates the conversation", number=4468)
#
# Issue #4468
# Title: Have an easy way to let the agent initiates the conversation
# State: open
# Created at: 2024-11-08 13:05:37+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4468
# --------------------------------------------------
# Issue(title="Azure OpenAI Embeddings not accepted by Astra DB component", number=4462)
#
# Issue #4462
# Title: Azure OpenAI Embeddings not accepted by Astra DB component
# State: open
# Created at: 2024-11-08 03:36:49+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4462
# --------------------------------------------------
# Issue(title="feat: Persist locked state for flows", number=4459)
#
# Issue #4459
# Title: feat: Persist locked state for flows
# State: open
# Created at: 2024-11-07 22:15:48+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4459
# --------------------------------------------------
# Issue(title="test: re-enable unit test", number=4455)
#
# Issue #4455
# Title: test: re-enable unit test
# State: open
# Created at: 2024-11-07 20:23:10+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4455
# --------------------------------------------------
# Issue(title="Error running graph: list index out of range", number=4441)
#
# Issue #4441
# Title: Error running graph: list index out of range
# State: open
# Created at: 2024-11-07 09:08:20+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4441
# --------------------------------------------------
# Issue(title="Unclosed event loop error when running langflow ", number=4436)
#
# Issue #4436
# Title: Unclosed event loop error when running langflow
# State: open
# Created at: 2024-11-07 01:38:12+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4436
# --------------------------------------------------
# Issue(title="session_id parameter in payload causes "Response 504" error in DataStax Langflow (11/6/24)", number=4434)
#
# Issue #4434
# Title: session_id parameter in payload causes "Response 504" error in DataStax Langflow (11/6/24)
# State: open
# Created at: 2024-11-06 22:32:17+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4434
# --------------------------------------------------
# Issue(title="New Store Message component (11/6/24) doesn't work without external memory", number=4433)
#
# Issue #4433
# Title: New Store Message component (11/6/24) doesn't work without external memory
# State: open
# Created at: 2024-11-06 22:19:54+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4433
# --------------------------------------------------
# Issue(title="New Store Message component in the latest DataStax Langflow (11/6/24) errors on Chat Output messages", number=4432)
#
# Issue #4432
# Title: New Store Message component in the latest DataStax Langflow (11/6/24) errors on Chat Output messages
# State: open
# Created at: 2024-11-06 22:13:49+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4432
# --------------------------------------------------
# Issue(title="adding schema in openAI component causes ValueError", number=4426)
#
# Issue #4426
# Title: adding schema in openAI component causes ValueError
# State: open
# Created at: 2024-11-06 18:13:08+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4426
# --------------------------------------------------
# Issue(title="Index_name Confusion of OpenSearch", number=4422)
#
# Issue #4422
# Title: Index_name Confusion of OpenSearch
# State: open
# Created at: 2024-11-06 10:53:23+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4422
# --------------------------------------------------
# Issue(title="Prevent Degradation of API Integration Example Code", number=4421)
#
# Issue #4421
# Title: Prevent Degradation of API Integration Example Code
# State: open
# Created at: 2024-11-06 10:50:02+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4421
# --------------------------------------------------
# Issue(title="fix: update Notify and Listen to inherit from Component", number=4413)
#
# Issue #4413
# Title: fix: update Notify and Listen to inherit from Component
# State: open
# Created at: 2024-11-05 19:44:04+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4413
# --------------------------------------------------
# Issue(title="Custom Component ID", number=4400)
#
# Issue #4400
# Title: Custom Component ID
# State: open
# Created at: 2024-11-05 10:43:10+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4400
# --------------------------------------------------
# Issue(title="does not seem to work with Groq or Ollama", number=4398)
#
# Issue #4398
# Title: does not seem to work with Groq or Ollama
# State: open
# Created at: 2024-11-05 09:34:07+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4398
# --------------------------------------------------
# Issue(title="Nothing displayed in logs tab of Component Output", number=4397)
#
# Issue #4397
# Title: Nothing displayed in logs tab of Component Output
# State: open
# Created at: 2024-11-05 09:15:50+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4397
# --------------------------------------------------
# Issue(title="the Directory plugin is not working in DS Langflow", number=4396)
#
# Issue #4396
# Title: the Directory plugin is not working in DS Langflow
# State: open
# Created at: 2024-11-05 09:13:09+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4396
# --------------------------------------------------
# Issue(title="Dynamic Agent template: OpenAI key error", number=4395)
#
# Issue #4395
# Title: Dynamic Agent template: OpenAI key error
# State: open
# Created at: 2024-11-05 09:07:24+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4395
# --------------------------------------------------
# Issue(title="performance of run_flow_from_json function", number=4394)
#
# Issue #4394
# Title: performance of run_flow_from_json function
# State: open
# Created at: 2024-11-05 06:28:14+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4394
# --------------------------------------------------
# Issue(title="feat: Add sqlite to blocking call detection", number=4376)
#
# Issue #4376
# Title: feat: Add sqlite to blocking call detection
# State: open
# Created at: 2024-11-04 12:04:46+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4376
# --------------------------------------------------
# Issue(title="perf: convert dependencies to async", number=4363)
#
# Issue #4363
# Title: perf: convert dependencies to async
# State: open
# Created at: 2024-11-02 00:52:22+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4363
# --------------------------------------------------
# Issue(title="fix: AstraDBCQLToolComponent", number=4356)
#
# Issue #4356
# Title: fix: AstraDBCQLToolComponent
# State: open
# Created at: 2024-11-01 18:32:24+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4356
# --------------------------------------------------
# Issue(title="when I call API, it return too many reply ,using the Document QA and openAImodelcomponent", number=4349)
#
# Issue #4349
# Title: when I call API, it return too many reply ,using the Document QA and openAImodelcomponent
# State: open
# Created at: 2024-11-01 08:33:30+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4349
# --------------------------------------------------
# Issue(title="Rewriting /etc/nginx/conf.d/default.conf crashes pod in read-only filesystem", number=4333)
#
# Issue #4333
# Title: Rewriting /etc/nginx/conf.d/default.conf crashes pod in read-only filesystem
# State: open
# Created at: 2024-10-31 11:58:21+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4333
# --------------------------------------------------
# Issue(title="Port is being assigned langflow service URL", number=4330)
#
# Issue #4330
# Title: Port is being assigned langflow service URL
# State: open
# Created at: 2024-10-31 08:36:01+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4330
# --------------------------------------------------
# Issue(title="feat: Add Ollama Image Description component", number=4327)
#
# Issue #4327
# Title: feat: Add Ollama Image Description component
# State: open
# Created at: 2024-10-30 16:28:27+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4327
# --------------------------------------------------
# Issue(title="feat: Custom Component for Langfuse environment variable", number=4323)
#
# Issue #4323
# Title: feat: Custom Component for Langfuse environment variable
# State: open
# Created at: 2024-10-29 21:48:22+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4323
# --------------------------------------------------
# Issue(title="Notify and Listen components throw error: object has no attribute 'build_results' + incompatible component inputs", number=4322)
#
# Issue #4322
# Title: Notify and Listen components throw error: object has no attribute 'build_results' + incompatible component inputs
# State: open
# Created at: 2024-10-29 21:26:14+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4322
# --------------------------------------------------
# Issue(title="How to delete logs", number=4297)
#
# Issue #4297
# Title: How to delete logs
# State: open
# Created at: 2024-10-27 21:09:29+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4297
# --------------------------------------------------
# Issue(title="How do i add a session id or user or custom metadata to Langfuse traces?", number=4274)
#
# Issue #4274
# Title: How do i add a session id or user or custom metadata to Langfuse traces?
# State: open
# Created at: 2024-10-24 18:32:55+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4274
# --------------------------------------------------
# Issue(title="Track Langflow Usage in langchain-astradb Components", number=4268)
#
# Issue #4268
# Title: Track Langflow Usage in langchain-astradb Components
# State: open
# Created at: 2024-10-24 14:43:46+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4268
# --------------------------------------------------
# Issue(title="Error in Zep Chat Memory "ImportError: Could not import zep-python package. Please install it with pip install zep-python."", number=4266)
#
# Issue #4266
# Title: Error in Zep Chat Memory "ImportError: Could not import zep-python package. Please install it with pip install zep-python."
# State: open
# Created at: 2024-10-24 14:14:20+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4266
# --------------------------------------------------
# Issue(title="Prompt combined multi-output from different agents with wrong content", number=4262)
#
# Issue #4262
# Title: Prompt combined multi-output from different agents with wrong content
# State: open
# Created at: 2024-10-24 05:55:07+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4262
# --------------------------------------------------
# Issue(title="No module named xxx when langflow run", number=4241)
#
# Issue #4241
# Title: No module named xxx when langflow run
# State: open
# Created at: 2024-10-22 16:46:13+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4241
# --------------------------------------------------
# Issue(title="Allow User Control Over ID Names After Component Name in API Configuration", number=4227)
#
# Issue #4227
# Title: Allow User Control Over ID Names After Component Name in API Configuration
# State: open
# Created at: 2024-10-21 14:51:53+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4227
# --------------------------------------------------
# Issue(title="Error building SQLDatabase component with unexpected keyword argument 'code'", number=4222)
#
# Issue #4222
# Title: Error building SQLDatabase component with unexpected keyword argument 'code'
# State: open
# Created at: 2024-10-21 12:15:39+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4222
# --------------------------------------------------
# Issue(title="Langflow traces are not well reflected in Langfuse", number=4212)
#
# Issue #4212
# Title: Langflow traces are not well reflected in Langfuse
# State: open
# Created at: 2024-10-19 15:56:38+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4212
# --------------------------------------------------
# Issue(title="feat: add support for DataStax Enterprise vector store", number=4198)
#
# Issue #4198
# Title: feat: add support for DataStax Enterprise vector store
# State: open
# Created at: 2024-10-18 04:01:08+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4198
# --------------------------------------------------
# Issue(title="Image File with Session ID in Chat Input breaks prompt ", number=4196)
#
# Issue #4196
# Title: Image File with Session ID in Chat Input breaks prompt
# State: open
# Created at: 2024-10-17 22:53:36+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4196
# --------------------------------------------------
# Issue(title="Inconsistent behavior after updating the name of a global variable", number=4191)
#
# Issue #4191
# Title: Inconsistent behavior after updating the name of a global variable
# State: open
# Created at: 2024-10-17 18:34:42+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4191
# --------------------------------------------------
# Issue(title="Railway install: No ability to create global variables", number=4186)
#
# Issue #4186
# Title: Railway install: No ability to create global variables
# State: open
# Created at: 2024-10-17 15:54:37+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4186
# --------------------------------------------------
# Issue(title="Custom Component Creation - Multiple Outputs Not Working in Versions 1.0.19 and Main", number=4185)
#
# Issue #4185
# Title: Custom Component Creation - Multiple Outputs Not Working in Versions 1.0.19 and Main
# State: open
# Created at: 2024-10-17 15:46:33+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4185
# --------------------------------------------------
# Issue(title="Frontend crashes when new project modal is opened.", number=4172)
#
# Issue #4172
# Title: Frontend crashes when new project modal is opened.
# State: open
# Created at: 2024-10-16 11:21:56+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4172
# --------------------------------------------------
# Issue(title="ImportError: cannot import name 'CodeInterpreter' from 'e2b_code_interpreter'", number=4164)
#
# Issue #4164
# Title: ImportError: cannot import name 'CodeInterpreter' from 'e2b_code_interpreter'
# State: open
# Created at: 2024-10-15 19:27:07+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4164
# --------------------------------------------------
# Issue(title="issue with langflow 1.0.19", number=4160)
#
# Issue #4160
# Title: issue with langflow 1.0.19
# State: open
# Created at: 2024-10-15 17:21:44+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4160
# --------------------------------------------------
# Issue(title="How to Enable SSL on langflow", number=4157)
#
# Issue #4157
# Title: How to Enable SSL on langflow
# State: open
# Created at: 2024-10-15 10:57:06+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4157
# --------------------------------------------------
# Issue(title="Able to set a component input as optional", number=4155)
#
# Issue #4155
# Title: Able to set a component input as optional
# State: open
# Created at: 2024-10-15 10:20:56+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4155
# --------------------------------------------------
# Issue(title="Understanding how the Custom components code is getting executed?", number=4152)
#
# Issue #4152
# Title: Understanding how the Custom components code is getting executed?
# State: open
# Created at: 2024-10-15 06:08:17+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4152
# --------------------------------------------------
# Issue(title="Incorrect default Curl snippet when tweaks are enabled in API tab.", number=4148)
#
# Issue #4148
# Title: Incorrect default Curl snippet when tweaks are enabled in API tab.
# State: open
# Created at: 2024-10-14 21:47:20+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4148
# --------------------------------------------------
# Issue(title="Improve JavaScript API Code Snippet in Modal", number=4147)
#
# Issue #4147
# Title: Improve JavaScript API Code Snippet in Modal
# State: open
# Created at: 2024-10-14 21:36:11+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4147
# --------------------------------------------------
# Issue(title="Add Chat Input Playground support for multiple images and different types of files", number=4145)
#
# Issue #4145
# Title: Add Chat Input Playground support for multiple images and different types of files
# State: open
# Created at: 2024-10-14 21:21:46+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4145
# --------------------------------------------------
# Issue(title="Use Monaco as code Editor for components", number=4136)
#
# Issue #4136
# Title: Use Monaco as code Editor for components
# State: open
# Created at: 2024-10-14 15:02:38+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4136
# --------------------------------------------------
# Issue(title="output format and documentation", number=4135)
#
# Issue #4135
# Title: output format and documentation
# State: open
# Created at: 2024-10-14 12:37:01+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4135
# --------------------------------------------------
# Issue(title="I can't upload a fille on DataStax Astra DataBase ", number=4125)
#
# Issue #4125
# Title: I can't upload a fille on DataStax Astra DataBase
# State: open
# Created at: 2024-10-13 10:52:26+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4125
# --------------------------------------------------
# Issue(title="Create jarvis.py", number=4124)
#
# Issue #4124
# Title: Create jarvis.py
# State: open
# Created at: 2024-10-12 16:18:06+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4124
# --------------------------------------------------
# Issue(title="feat: Add new Excel to Data component", number=4116)
#
# Issue #4116
# Title: feat: Add new Excel to Data component
# State: open
# Created at: 2024-10-11 15:57:46+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4116
# --------------------------------------------------
# Issue(title="perf: startup", number=4113)
#
# Issue #4113
# Title: perf: startup
# State: open
# Created at: 2024-10-11 13:32:44+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4113
# --------------------------------------------------
# Issue(title="Question is it possible to implement multi-agent flows using langgraph in Langflow?", number=4090)
#
# Issue #4090
# Title: Question is it possible to implement multi-agent flows using langgraph in Langflow?
# State: open
# Created at: 2024-10-10 00:15:08+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4090
# --------------------------------------------------
# Issue(title="switched enviro and back - relaunch langflow - can see flows - but when clciking - get 'Sorry, we found an unexpected error!  Please report errors with detailed tracebacks on the GitHub Issues page. Thank you!", number=4080)
#
# Issue #4080
# Title: switched enviro and back - relaunch langflow - can see flows - but when clciking - get 'Sorry, we found an unexpected error!  Please report errors with detailed tracebacks on the GitHub Issues page. Thank you!
# State: open
# Created at: 2024-10-09 13:43:43+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4080
# --------------------------------------------------
# Issue(title="remove span from custom select", number=4073)
#
# Issue #4073
# Title: remove span from custom select
# State: open
# Created at: 2024-10-08 21:00:19+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4073
# --------------------------------------------------
# Issue(title="ci: more uv cleanup", number=4072)
#
# Issue #4072
# Title: ci: more uv cleanup
# State: open
# Created at: 2024-10-08 20:13:11+00:00
# URL: https://github.com/langflow-ai/langflow/pull/4072
# --------------------------------------------------
# Issue(title="How can i add meta-data to File component ? ", number=4065)
#
# Issue #4065
# Title: How can i add meta-data to File component ?
# State: open
# Created at: 2024-10-08 04:10:35+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4065
# --------------------------------------------------
# Issue(title="How can I unchange the component id , when i import json ?", number=4063)
#
# Issue #4063
# Title: How can I unchange the component id , when i import json ?
# State: open
# Created at: 2024-10-07 23:48:57+00:00
# URL: https://github.com/langflow-ai/langflow/issues/4063
# --------------------------------------------------
# Issue(title="Variables don't automatically import when injected via environment variables", number=4049)
#
# Issue #4049
# Title: Variables don't automatically import when injected via environment variables
# State: open
# ...
#
# Issue #3731
# Title: Docker tag latest na verdade está baixando a versão 0.0.95
# State: open
# Created at: 2024-09-09 14:46:16+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3731
# --------------------------------------------------
# Issue(title="feat: add cloudflare workers ai embeddings", number=3697)
#
# Issue #3697
# Title: feat: add cloudflare workers ai embeddings
# State: open
# Created at: 2024-09-05 14:22:02+00:00
# URL: https://github.com/langflow-ai/langflow/pull/3697
# --------------------------------------------------
# Issue(title="fix: Problem in the "description" field when using MySQL (#3678)", number=3679)
#
# Issue #3679
# Title: fix: Problem in the "description" field when using MySQL (#3678)
# State: open
# Created at: 2024-09-04 09:35:41+00:00
# URL: https://github.com/langflow-ai/langflow/pull/3679
# --------------------------------------------------
# Issue(title="fix: Problem in the "description" field when using  MySQL", number=3678)
#
# Issue #3678
# Title: fix: Problem in the "description" field when using  MySQL
# State: open
# Created at: 2024-09-04 09:01:57+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3678
# --------------------------------------------------
# Issue(title="Json output inside Vertex / Gemini component", number=3677)
#
# Issue #3677
# Title: Json output inside Vertex / Gemini component
# State: open
# Created at: 2024-09-04 08:23:14+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3677
# --------------------------------------------------
# Issue(title="Stop button not working on backend.", number=3670)
#
# Issue #3670
# Title: Stop button not working on backend.
# State: open
# Created at: 2024-09-03 17:21:57+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3670
# --------------------------------------------------
# Issue(title="use the new model_fields attribute instead of the deprecated __fields__ attribute", number=3666)
#
# Issue #3666
# Title: use the new model_fields attribute instead of the deprecated __fields__ attribute
# State: open
# Created at: 2024-09-03 10:43:45+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3666
# --------------------------------------------------
# Issue(title="[FEATURE] Show Crew AI messages during Sequential work. Promising platform. ", number=3640)
#
# Issue #3640
# Title: [FEATURE] Show Crew AI messages during Sequential work. Promising platform.
# State: open
# Created at: 2024-08-31 21:17:04+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3640
# --------------------------------------------------
# Issue(title="LangFlow can't run in the same environment than LangGraph SDK", number=3621)
#
# Issue #3621
# Title: LangFlow can't run in the same environment than LangGraph SDK
# State: open
# Created at: 2024-08-29 20:21:43+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3621
# --------------------------------------------------
# Issue(title="build(deps): bump webpack from 5.93.0 to 5.94.0 in /docs", number=3583)
#
# Issue #3583
# Title: build(deps): bump webpack from 5.93.0 to 5.94.0 in /docs
# State: open
# Created at: 2024-08-27 23:22:39+00:00
# URL: https://github.com/langflow-ai/langflow/pull/3583
# --------------------------------------------------
# Issue(title="feat: allow drive loader to read a folder recursively", number=3572)
#
# Issue #3572
# Title: feat: allow drive loader to read a folder recursively
# State: open
# Created at: 2024-08-27 13:21:41+00:00
# URL: https://github.com/langflow-ai/langflow/pull/3572
# --------------------------------------------------
# Issue(title="OpenAi Embedding Component: Error Building Component RedisCache only accepts values that can be pickled.", number=3561)
#
# Issue #3561
# Title: OpenAi Embedding Component: Error Building Component RedisCache only accepts values that can be pickled.
# State: open
# Created at: 2024-08-26 23:32:40+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3561
# --------------------------------------------------
# Issue(title="Voyage embedding component", number=3557)
#
# Issue #3557
# Title: Voyage embedding component
# State: open
# Created at: 2024-08-26 20:46:59+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3557
# --------------------------------------------------
# Issue(title="build(deps): bump micromatch from 4.0.7 to 4.0.8 in /docs", number=3534)
#
# Issue #3534
# Title: build(deps): bump micromatch from 4.0.7 to 4.0.8 in /docs
# State: open
# Created at: 2024-08-23 19:02:21+00:00
# URL: https://github.com/langflow-ai/langflow/pull/3534
# --------------------------------------------------
# Issue(title="Multi-Channel Support and Website Integration ", number=3499)
#
# Issue #3499
# Title: Multi-Channel Support and Website Integration
# State: open
# Created at: 2024-08-22 10:12:24+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3499
# --------------------------------------------------
# Issue(title="Does langflow support high-availability deployments？", number=3494)
#
# Issue #3494
# Title: Does langflow support high-availability deployments？
# State: open
# Created at: 2024-08-22 04:02:21+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3494
# --------------------------------------------------
# Issue(title="Streaming URL is not unique in multi-user environment", number=3468)
#
# Issue #3468
# Title: Streaming URL is not unique in multi-user environment
# State: open
# Created at: 2024-08-21 09:47:24+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3468
# --------------------------------------------------
# Issue(title="Publish Chat as a Single-page Web App", number=3467)
#
# Issue #3467
# Title: Publish Chat as a Single-page Web App
# State: open
# Created at: 2024-08-21 09:26:24+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3467
# --------------------------------------------------
# Issue(title="Enhance Markdown render in playground chat", number=3456)
#
# Issue #3456
# Title: Enhance Markdown render in playground chat
# State: open
# Created at: 2024-08-20 19:20:52+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3456
# --------------------------------------------------
# Issue(title="Remove Langlflow setting/ Langflow Api ("ENABLE_API": false)", number=3443)
#
# Issue #3443
# Title: Remove Langlflow setting/ Langflow Api ("ENABLE_API": false)
# State: open
# Created at: 2024-08-20 10:04:10+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3443
# --------------------------------------------------
# Issue(title="Can we make TracingService optional, similar to LANGFLOW_DO_NOT_TRACK?", number=3441)
#
# Issue #3441
# Title: Can we make TracingService optional, similar to LANGFLOW_DO_NOT_TRACK?
# State: open
# Created at: 2024-08-20 01:22:56+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3441
# --------------------------------------------------
# Issue(title="Cannot find file cdk.Dockerfile when using AWS CDK", number=3440)
#
# Issue #3440
# Title: Cannot find file cdk.Dockerfile when using AWS CDK
# State: open
# Created at: 2024-08-20 00:40:24+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3440
# --------------------------------------------------
# Issue(title="The LLM's response is generator and cannot be pickle", number=3423)
#
# Issue #3423
# Title: The LLM's response is generator and cannot be pickle
# State: open
# Created at: 2024-08-19 08:24:03+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3423
# --------------------------------------------------
# Issue(title="Ai assistant", number=3421)
#
# Issue #3421
# Title: Ai assistant
# State: open
# Created at: 2024-08-19 06:13:31+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3421
# --------------------------------------------------
# Issue(title="Allow changing branding settings (e.g. showing/hiding DataStax logo) without rebuilding the app", number=3394)
#
# Issue #3394
# Title: Allow changing branding settings (e.g. showing/hiding DataStax logo) without rebuilding the app
# State: open
# Created at: 2024-08-16 18:43:34+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3394
# --------------------------------------------------
# Issue(title="when I call the flow by curl, it output a big json filled with output in flow 6 times, how can I get only 1 output", number=3378)
#
# Issue #3378
# Title: when I call the flow by curl, it output a big json filled with output in flow 6 times, how can I get only 1 output
# State: open
# Created at: 2024-08-16 09:57:09+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3378
# --------------------------------------------------
# Issue(title="build: Add transformers to pyproject.toml", number=3374)
#
# Issue #3374
# Title: build: Add transformers to pyproject.toml
# State: open
# Created at: 2024-08-15 22:44:51+00:00
# URL: https://github.com/langflow-ai/langflow/pull/3374
# --------------------------------------------------
# Issue(title="feat: Add IBM Watsonx Model Component", number=3373)
#
# Issue #3373
# Title: feat: Add IBM Watsonx Model Component
# State: open
# Created at: 2024-08-15 22:31:08+00:00
# URL: https://github.com/langflow-ai/langflow/pull/3373
# --------------------------------------------------
# Issue(title="ci: add arm64 to docker build", number=3345)
#
# Issue #3345
# Title: ci: add arm64 to docker build
# State: open
# Created at: 2024-08-14 16:58:26+00:00
# URL: https://github.com/langflow-ai/langflow/pull/3345
# --------------------------------------------------
# Issue(title="Whole flows disappearing when opened, then disappearing from the folder completely", number=3324)
#
# Issue #3324
# Title: Whole flows disappearing when opened, then disappearing from the folder completely
# State: open
# Created at: 2024-08-14 06:48:09+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3324
# --------------------------------------------------
# Issue(title="refactor: repository pattern", number=3286)
#
# Issue #3286
# Title: refactor: repository pattern
# State: open
# Created at: 2024-08-12 08:31:41+00:00
# URL: https://github.com/langflow-ai/langflow/pull/3286
# --------------------------------------------------
# Issue(title="While importing data into chroma, the langchain backend POD failed to respond to /health, and got killed.", number=3243)
#
# Issue #3243
# Title: While importing data into chroma, the langchain backend POD failed to respond to /health, and got killed.
# State: open
# Created at: 2024-08-08 12:23:57+00:00
# URL: https://github.com/langflow-ai/langflow/issues/3243
# --------------------------------------------------
# Issue(title="feat: Add selenium dependency for web scraping", number=3212)
#
# Issue #3212
# Title: feat: Add selenium dependency for web scraping
# State: open
# Created at: 2024-08-06 04:04:47+00:00
# URL: https://github.com/langflow-ai/langflow/pull/3212
# --------------------------------------------------
# Issue(title="feat: add code generation from Graphs generated in Python", number=3205)
#
# Issue #3205
# Title: feat: add code generation from Graphs generated in Python
# State: open
# Created at: 2024-08-05 20:27:44+00:00
# URL: https://github.com/langflow-ai/langflow/pull/3205
# --------------------------------------------------
# Issue(title="AgentOps Integration", number=2958)
#
# Issue #2958
# Title: AgentOps Integration
# State: open
# Created at: 2024-07-25 17:10:21+00:00
# URL: https://github.com/langflow-ai/langflow/pull/2958
# --------------------------------------------------
# Issue(title="Snap to grid, areas, notes, widget colors", number=2914)
#
# Issue #2914
# Title: Snap to grid, areas, notes, widget colors
# State: open
# Created at: 2024-07-24 11:34:21+00:00
# URL: https://github.com/langflow-ai/langflow/issues/2914
# --------------------------------------------------
# Issue(title="Make List[dict] field available for input", number=2913)
#
# Issue #2913
# Title: Make List[dict] field available for input
# State: open
# Created at: 2024-07-24 11:23:19+00:00
# URL: https://github.com/langflow-ai/langflow/issues/2913
# --------------------------------------------------
# Issue(title="add docker image for arm64", number=2857)
#
# Issue #2857
# Title: add docker image for arm64
# State: open
# Created at: 2024-07-21 17:09:20+00:00
# URL: https://github.com/langflow-ai/langflow/pull/2857
# --------------------------------------------------
# Issue(title="Single Sign On (SSO) support with OIDC or OAuth2", number=2855)
#
# Issue #2855
# Title: Single Sign On (SSO) support with OIDC or OAuth2
# State: open
# Created at: 2024-07-20 20:14:50+00:00
# URL: https://github.com/langflow-ai/langflow/issues/2855
# --------------------------------------------------
# Issue(title="deploy: AWS Elastic Beanstalk Quickstart for Langflow", number=2837)
#
# Issue #2837
# Title: deploy: AWS Elastic Beanstalk Quickstart for Langflow
# State: open
# Created at: 2024-07-19 17:13:30+00:00
# URL: https://github.com/langflow-ai/langflow/pull/2837
# --------------------------------------------------
# Issue(title="[Issue] Can not get pods working - Back-off restarting failed", number=2831)
#
# Issue #2831
# Title: [Issue] Can not get pods working - Back-off restarting failed
# State: open
# Created at: 2024-07-19 14:56:26+00:00
# URL: https://github.com/langflow-ai/langflow/issues/2831
# --------------------------------------------------
# Issue(title="[Feature Request] Component Copy and Paste Between Flows", number=2821)
#
# Issue #2821
# Title: [Feature Request] Component Copy and Paste Between Flows
# State: open
# Created at: 2024-07-19 04:47:47+00:00
# URL: https://github.com/langflow-ai/langflow/issues/2821
# --------------------------------------------------
# Issue(title="deploy: Add support for Langflow Azure ARM Quickstart", number=2786)
#
# Issue #2786
# Title: deploy: Add support for Langflow Azure ARM Quickstart
# State: open
# Created at: 2024-07-18 12:34:58+00:00
# URL: https://github.com/langflow-ai/langflow/pull/2786
# --------------------------------------------------
# Issue(title="Added a Tutorial for Basic ChatBot", number=2644)
#
# Issue #2644
# Title: Added a Tutorial for Basic ChatBot
# State: open
# Created at: 2024-07-11 19:59:22+00:00
# URL: https://github.com/langflow-ai/langflow/pull/2644
# --------------------------------------------------
# Issue(title="API Stream leak ", number=2563)
#
# Issue #2563
# Title: API Stream leak
# State: open
# Created at: 2024-07-05 19:14:10+00:00
# URL: https://github.com/langflow-ai/langflow/issues/2563
# --------------------------------------------------
# Issue(title="Add internationalization configuration to the front-end", number=2149)
#
# Issue #2149
# Title: Add internationalization configuration to the front-end
# State: open
# Created at: 2024-06-12 10:25:13+00:00
# URL: https://github.com/langflow-ai/langflow/pull/2149
# --------------------------------------------------
# Issue(title="Integrating Custom Callback to Output Agent Steps in Recode Format", number=2120)
#
# Issue #2120
# Title: Integrating Custom Callback to Output Agent Steps in Recode Format
# State: open
# Created at: 2024-06-09 22:36:04+00:00
# URL: https://github.com/langflow-ai/langflow/issues/2120
# --------------------------------------------------
# Issue(title="Request for ARM64 Support in LangFlow Docker Images", number=1976)
#
# Issue #1976
# Title: Request for ARM64 Support in LangFlow Docker Images
# State: open
# Created at: 2024-05-26 14:30:14+00:00
# URL: https://github.com/langflow-ai/langflow/issues/1976
# --------------------------------------------------
# Issue(title="[Feature Request] Collaborative/Access Control enhancement ", number=1864)
#
# Issue #1864
# Title: [Feature Request] Collaborative/Access Control enhancement
# State: open
# Created at: 2024-05-08 08:36:55+00:00
# URL: https://github.com/langflow-ai/langflow/issues/1864
# --------------------------------------------------
# Issue(title="[Feature Request] Langflow Graph: Integrate Direct Management Tools to Replace LangGraph with Equivalent Functionalities", number=1738)
#
# Issue #1738
# Title: [Feature Request] Langflow Graph: Integrate Direct Management Tools to Replace LangGraph with Equivalent Functionalities
# State: open
# Created at: 2024-04-17 07:27:04+00:00
# URL: https://github.com/langflow-ai/langflow/issues/1738
# --------------------------------------------------
# Issue(title="open webui integration ", number=1520)
#
# Issue #1520
# Title: open webui integration
# State: open
# Created at: 2024-03-13 21:20:41+00:00
# URL: https://github.com/langflow-ai/langflow/issues/1520
# --------------------------------------------------
